# %% [markdown]
# <a href="https://colab.research.google.com/github/Ivan8Garcia/data-science/blob/main/inmuebles_cdmx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PANDAS**

# %% [markdown]
# ## **Importando la base de datos**

# %%
import pandas as pd

url= "https://gist.githubusercontent.com/ahcamachod/a572cfcc2527046db93101f88011b26e/raw/ffb13f45a79d31223e645611a119397dd127ee3c/alquiler.csv"
pd.read_csv(url)
# Out:
#       Tipo;Colonia;Habitaciones;Garages;Suites;Area;Valor;Condominio;Impuesto
# 0          Cocineta;Condesa;1;0;0;40;5950.0;1750.0;210.0
# 1                       Casa;Polanco;2;0;1;100;24500.0;;
# 2      Conjunto Comercial/Sala;Santa Fe;0;4;0;150;182...
# 3      Departamento;Centro Histórico;1;0;0;15;2800.0;...
# 4          Departamento;Del Valle;1;0;0;48;2800.0;805.0;
# ...                                                  ...
# 25116  Cochera/Estacionamiento;Centro Histórico;0;0;0...
# 25117  Cocineta;Centro Histórico;0;0;0;27;2800.0;1225...
# 25118  Departamento;Mixcoac;2;1;0;48;4900.0;1781.5;129.5
# 25119  Departamento;Lomas de Chapultepec;2;0;0;70;105...
# 25120  Conjunto Comercial/Sala;Centro Histórico;0;0;0...
#
# [25121 rows x 1 columns]

# %%
pd.read_csv(url, sep=";")
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 0           0    40   5950.0      1750.0     210.0
# 1           1   100  24500.0         NaN       NaN
# 2           0   150  18200.0     14070.0    3888.5
# 3           0    15   2800.0      1365.0      70.0
# 4           0    48   2800.0       805.0       NaN
# ...       ...   ...      ...         ...       ...
# 25116       0   755  49000.0         NaN       NaN
# 25117       0    27   2800.0      1225.0      87.5
# 25118       0    48   4900.0      1781.5     129.5
# 25119       0    70  10500.0      2660.0       NaN
# 25120       0   250  22750.0     14721.0    3881.5
#
# [25121 rows x 9 columns]

# %%
datos= pd.read_csv(url, sep=";")
datos
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 0           0    40   5950.0      1750.0     210.0
# 1           1   100  24500.0         NaN       NaN
# 2           0   150  18200.0     14070.0    3888.5
# 3           0    15   2800.0      1365.0      70.0
# 4           0    48   2800.0       805.0       NaN
# ...       ...   ...      ...         ...       ...
# 25116       0   755  49000.0         NaN       NaN
# 25117       0    27   2800.0      1225.0      87.5
# 25118       0    48   4900.0      1781.5     129.5
# 25119       0    70  10500.0      2660.0       NaN
# 25120       0   250  22750.0     14721.0    3881.5
#
# [25121 rows x 9 columns]

# %%
## En la parte de arriba estamos viendo nuestros datos pero no se una manera tan buena, es decir, nos muestra los primeros 4 y despues los ultimos 4,
 #osea no toda la lista completa

# %%
# esta es para ver los primeros 5 datos
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN

# %%
#esta es para ver los ultimos 5 datos
datos.tail()
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 25116       0   755  49000.0         NaN       NaN
# 25117       0    27   2800.0      1225.0      87.5
# 25118       0    48   4900.0      1781.5     129.5
# 25119       0    70  10500.0      2660.0       NaN
# 25120       0   250  22750.0     14721.0    3881.5

# %%
#aqui es para visualizar los primeros 10 datos
datos.head(10)
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
# 5       Casa de Condominio          Santa Fe             5        4       5
# 6  Conjunto Comercial/Sala  Centro Histórico             0        3       0
# 7             Departamento  Centro Histórico             1        0       0
# 8             Departamento           Condesa             1        0       1
# 9                 Cocineta           Condesa             1        0       0
#
#    Area     Valor  Condominio  Impuesto
# 0    40    5950.0      1750.0     210.0
# 1   100   24500.0         NaN       NaN
# 2   150   18200.0     14070.0    3888.5
# 3    15    2800.0      1365.0      70.0
# 4    48    2800.0       805.0       NaN
# 5   750   77000.0         NaN       NaN
# 6   695  122500.0     67175.5   10605.0
# 7    36    4200.0         NaN       NaN
# 8    40    7000.0      1963.5     175.0
# 9    27    6300.0      1753.5       NaN

# %%
#aqui es para elegir aleatoriamente una muestra de 10 datos
datos.sample(10)
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 4574              Departamento               Condesa             3        1
# 2402              Departamento              Narvarte             1        0
# 4996   Conjunto Comercial/Sala               Condesa             0        1
# 24763             Departamento                  Roma             2        0
# 15696  Conjunto Comercial/Sala      Centro Histórico             0        0
# 4055              Departamento                  Roma             2        1
# 16381             Departamento               Polanco             2        1
# 1673              Departamento              Santa Fe             3        2
# 24526             Departamento                  Roma             1        0
# 24717             Departamento  Bosques de las Lomas             3        2
#
#        Suites  Area    Valor  Condominio  Impuesto
# 4574        0   122   9450.0      4907.0     654.5
# 2402        0    80   6650.0      1925.0     178.5
# 4996        0    22   3500.0      2240.0     535.5
# 24763       2    59   7000.0      2240.0     847.0
# 15696       0   390  42000.0     30800.0    4847.5
# 4055        1    90  17500.0      7350.0     735.0
# 16381       0    90   6300.0      3115.0     731.5
# 1673        3   105  11550.0      5250.0     945.0
# 24526       0    45   6965.0      1680.0      70.0
# 24717       1   118  17150.0      4158.0    1582.0

# %%
#dataframe es una estructura de TABLA
type(datos)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ##**Exploracion inicial de los datos**

# %%
datos.sample(5)
# Out:
#                           Tipo     Colonia  Habitaciones  Garages  Suites  \
# 24090             Tienda/Salón  La Florida             0        0       0
# 11841             Departamento    Narvarte             2        0       0
# 20965             Tienda/Salón    Coyoacán             0        0       0
# 1372   Conjunto Comercial/Sala    Santa Fe             0        1       0
# 16142             Departamento    Santa Fe             2        1       1
#
#        Area    Valor  Condominio  Impuesto
# 24090   197  31500.0         NaN    2625.0
# 11841    60   3850.0      2187.5    1697.5
# 20965    24   4200.0      3363.5     556.5
# 1372     40   9100.0     28927.5     542.5
# 16142    72   5600.0      3398.5       NaN

# %%
datos.shape
# Out:
# (25121, 9)

# %%
datos.columns
# Out:
# Index(['Tipo', 'Colonia', 'Habitaciones', 'Garages', 'Suites', 'Area', 'Valor',
#        'Condominio', 'Impuesto'],
#       dtype='object')

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25121 entries, 0 to 25120
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          25121 non-null  object
#  1   Colonia       25121 non-null  object
#  2   Habitaciones  25121 non-null  int64
#  3   Garages       25121 non-null  int64
#  4   Suites        25121 non-null  int64
#  5   Area          25121 non-null  int64
#  6   Valor         25107 non-null  float64
#  7   Condominio    22495 non-null  float64
#  8   Impuesto      18037 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %%
datos["Tipo"]
# Out:
# 0                       Cocineta
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                   Departamento
# 4                   Departamento
#                   ...
# 25116    Cochera/Estacionamiento
# 25117                   Cocineta
# 25118               Departamento
# 25119               Departamento
# 25120    Conjunto Comercial/Sala
# Name: Tipo, Length: 25121, dtype: object

# %%
datos[["Habitaciones","Valor"]]
# Out:
#        Habitaciones    Valor
# 0                 1   5950.0
# 1                 2  24500.0
# 2                 0  18200.0
# 3                 1   2800.0
# 4                 1   2800.0
# ...             ...      ...
# 25116             0  49000.0
# 25117             0   2800.0
# 25118             2   4900.0
# 25119             2  10500.0
# 25120             0  22750.0
#
# [25121 rows x 2 columns]

# %% [markdown]
# ##**Demandas de ML (machine learning)**

# %% [markdown]
# ###**Analisis exploratorio de los datos**

# %% [markdown]
# #### **¿Cuales son los valores promedio de alquiler por tipo de propiedad?**

# %%
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN

# %%
datos["Valor"].mean()
# Out:
# np.float64(36885.05048392878)

# %%
##usaremos groupby para agrupar primero los valores por la columna TIPO
datos.groupby("Tipo").mean(numeric_only=True)
# Out:
#                             Habitaciones    Garages     Suites          Area  \
# Tipo
# Casa                            3.359633   1.897248   1.438532    289.943119
# Casa Comercial                  1.801980   2.118812   0.257426    370.277228
# Casa de Condominio              4.319672   3.555738   3.247541    566.303279
# Casa de Vecindad                1.974684   0.379747   0.215190     79.981013
# Cochera/Estacionamiento         0.064935   1.376623   0.000000     18.662338
# Cocineta                        0.836088   0.020661   0.041322     29.090909
# Conjunto Comercial/Sala         0.047175   2.686323   0.000352    236.323711
# Departamento                    2.504199   1.256367   0.891899    124.014292
# Departamento en Hotel           1.419780   0.969231   0.758242     65.848352
# Edificio Completo               0.405530  11.175115   0.027650   1717.271889
# Estudio                         0.500000   0.250000   0.000000    103.250000
# Galpón/Depósito/Almacén         0.069204   5.311419   0.000000   2660.487889
# Hotel                          25.500000   2.500000  12.000000    885.500000
# Industria                       0.000000   0.000000   0.000000     22.000000
# Loft                            1.078947   0.552632   0.421053     56.263158
# Loteo/Condominio                0.000000   0.000000   0.000000    215.000000
# Posada/Chalé                   23.000000   0.000000  23.000000    862.000000
# Rancho                          5.125000   0.000000   3.750000  14993.750000
# Terreno Estándar                0.066667   0.000000   0.000000   4012.044444
# Tienda en Centro Comercial      0.055838   8.385787   0.010152     92.197970
# Tienda/Salón                    0.011840   1.349727   0.001821    242.169399
#
#                                     Valor     Condominio      Impuesto
# Tipo
# Casa                         31453.177064    3699.421642   6629.404851
# Casa Comercial               54735.841584    7622.192308   6166.063380
# Casa de Condominio           51428.609836    5286.578804  15046.939394
# Casa de Vecindad              5961.740506     413.444444    706.850000
# Cochera/Estacionamiento       6995.454545    1069.075000    449.458333
# Cocineta                      4425.856061    1521.734214    280.701461
# Conjunto Comercial/Sala      57675.214550   17489.361142   5425.980245
# Departamento                 18683.269431    6797.092951   2634.921081
# Departamento en Hotel        16285.430769    7250.650602   1768.923885
# Edificio Completo           409418.080645  234304.608696  50413.735294
# Estudio                       8400.000000    1921.500000    529.375000
# Galpón/Depósito/Almacén     299984.140138   48581.166667  22260.530899
# Hotel                        87500.000000            NaN  21707.000000
# Industria                   420000.000000            NaN           NaN
# Loft                          9924.526316    3501.200000    887.080645
# Loteo/Condominio             92166.666667            NaN  17097.500000
# Posada/Chalé                  5180.000000    1032.500000           NaN
# Rancho                       38014.375000            NaN   4375.000000
# Terreno Estándar            135364.444444            NaN  24988.750000
# Tienda en Centro Comercial   32556.785714    6824.166667   4127.755882
# Tienda/Salón                 56263.544252   10395.491137  10532.468927

# %%
## especificamos  entre corchetes la columna VALOR para sacar el promedio solamente a esa columna
datos.groupby("Tipo")["Valor"].mean()
# Out:
# Tipo
# Casa                           31453.177064
# Casa Comercial                 54735.841584
# Casa de Condominio             51428.609836
# Casa de Vecindad                5961.740506
# Cochera/Estacionamiento         6995.454545
# Cocineta                        4425.856061
# Conjunto Comercial/Sala        57675.214550
# Departamento                   18683.269431
# Departamento en Hotel          16285.430769
# Edificio Completo             409418.080645
# Estudio                         8400.000000
# Galpón/Depósito/Almacén       299984.140138
# Hotel                          87500.000000
# Industria                     420000.000000
# Loft                            9924.526316
# Loteo/Condominio               92166.666667
# Posada/Chalé                    5180.000000
# Rancho                         38014.375000
# Terreno Estándar              135364.444444
# Tienda en Centro Comercial     32556.785714
# Tienda/Salón                   56263.544252
# Name: Valor, dtype: float64

# %%
## ahora agregamos otro corchete para covertirlo a DATA FRAME
datos.groupby("Tipo")[["Valor"]].mean().sort_values("Valor")
# Out:
#                                     Valor
# Tipo
# Cocineta                      4425.856061
# Posada/Chalé                  5180.000000
# Casa de Vecindad              5961.740506
# Cochera/Estacionamiento       6995.454545
# Estudio                       8400.000000
# Loft                          9924.526316
# Departamento en Hotel        16285.430769
# Departamento                 18683.269431
# Casa                         31453.177064
# Tienda en Centro Comercial   32556.785714
# Rancho                       38014.375000
# Casa de Condominio           51428.609836
# Casa Comercial               54735.841584
# Tienda/Salón                 56263.544252
# Conjunto Comercial/Sala      57675.214550
# Hotel                        87500.000000
# Loteo/Condominio             92166.666667
# Terreno Estándar            135364.444444
# Galpón/Depósito/Almacén     299984.140138
# Edificio Completo           409418.080645
# Industria                   420000.000000

# %%
df_tipo_precio= datos.groupby("Tipo")[["Valor"]].mean().sort_values("Valor")
df_tipo_precio.plot(kind="barh", figsize=(12,7), color="red")
# Out:
# <Axes: ylabel='Tipo'>

# %%
datos.Tipo.unique()
# Out:
# array(['Cocineta', 'Casa', 'Conjunto Comercial/Sala', 'Departamento',
#        'Casa de Condominio', 'Edificio Completo', 'Departamento en Hotel',
#        'Tienda/Salón', 'Casa Comercial', 'Casa de Vecindad',
#        'Terreno Estándar', 'Cochera/Estacionamiento', 'Loft',
#        'Galpón/Depósito/Almacén', 'Tienda en Centro Comercial', 'Rancho',
#        'Posada/Chalé', 'Estudio', 'Hotel', 'Loteo/Condominio',
#        'Industria'], dtype=object)

# %%
inmuebles_comerciales=['Conjunto Comercial/Sala', 'Edificio Completo',
       'Tienda/Salón', 'Casa Comercial',
       'Terreno Estándar', 'Cochera/Estacionamiento',
       'Galpón/Depósito/Almacén', 'Tienda en Centro Comercial', 'Hotel', 'Loteo/Condominio',
       'Industria']

# %%
datos.query("@inmuebles_comerciales in Tipo")
# Out:
#                           Tipo           Colonia  Habitaciones  Garages  \
# 2      Conjunto Comercial/Sala          Santa Fe             0        4
# 6      Conjunto Comercial/Sala  Centro Histórico             0        3
# 11           Edificio Completo              Roma             0        0
# 24     Conjunto Comercial/Sala          Santa Fe             0        1
# 26     Conjunto Comercial/Sala  Centro Histórico             0        5
# ...                        ...               ...           ...      ...
# 25107  Conjunto Comercial/Sala          Santa Fe             0        1
# 25110  Conjunto Comercial/Sala  Centro Histórico             0        0
# 25112  Conjunto Comercial/Sala  Centro Histórico             0        0
# 25116  Cochera/Estacionamiento  Centro Histórico             0        0
# 25120  Conjunto Comercial/Sala  Centro Histórico             0        0
#
#        Suites  Area     Valor  Condominio  Impuesto
# 2           0   150   18200.0     14070.0    3888.5
# 6           0   695  122500.0     67175.5   10605.0
# 11          0   536   98000.0         NaN   12470.5
# 24          0    22    2450.0         NaN       NaN
# 26          0  1306  411390.0     68201.0       NaN
# ...       ...   ...       ...         ...       ...
# 25107       0    55    7000.0      3836.0       NaN
# 25110       0   140   14000.0      4942.0    1736.0
# 25112       0    32    2100.0      3622.5     290.5
# 25116       0   755   49000.0         NaN       NaN
# 25120       0   250   22750.0     14721.0    3881.5
#
# [7812 rows x 9 columns]

# %%
datos.query("@inmuebles_comerciales not in Tipo")
# Out:
#                      Tipo               Colonia  Habitaciones  Garages  \
# 0                Cocineta               Condesa             1        0
# 1                    Casa               Polanco             2        0
# 3            Departamento      Centro Histórico             1        0
# 4            Departamento             Del Valle             1        0
# 5      Casa de Condominio              Santa Fe             5        4
# ...                   ...                   ...           ...      ...
# 25114        Departamento              Narvarte             1        0
# 25115  Casa de Condominio              Santa Fe             5        3
# 25117            Cocineta      Centro Histórico             0        0
# 25118        Departamento               Mixcoac             2        1
# 25119        Departamento  Lomas de Chapultepec             2        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 0           0    40   5950.0      1750.0     210.0
# 1           1   100  24500.0         NaN       NaN
# 3           0    15   2800.0      1365.0      70.0
# 4           0    48   2800.0       805.0       NaN
# 5           5   750  77000.0         NaN       NaN
# ...       ...   ...      ...         ...       ...
# 25114       0    28   3500.0      1260.0      87.5
# 25115       4   450  52500.0      5988.5    8162.0
# 25117       0    27   2800.0      1225.0      87.5
# 25118       0    48   4900.0      1781.5     129.5
# 25119       0    70  10500.0      2660.0       NaN
#
# [17309 rows x 9 columns]

# %%
df=datos.query("@inmuebles_comerciales not in Tipo")
df.head()
# Out:
#                  Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 0            Cocineta           Condesa             1        0       0    40
# 1                Casa           Polanco             2        0       1   100
# 3        Departamento  Centro Histórico             1        0       0    15
# 4        Departamento         Del Valle             1        0       0    48
# 5  Casa de Condominio          Santa Fe             5        4       5   750
#
#      Valor  Condominio  Impuesto
# 0   5950.0      1750.0     210.0
# 1  24500.0         NaN       NaN
# 3   2800.0      1365.0      70.0
# 4   2800.0       805.0       NaN
# 5  77000.0         NaN       NaN

# %%
df_tipo_precio= df.groupby("Tipo")[["Valor"]].mean().sort_values("Valor")
df_tipo_precio.plot(kind="barh", figsize=(12,7), color="red")
# Out:
# <Axes: ylabel='Tipo'>

# %% [markdown]
# ####Porcentaje de cada tipo de inmueble presente en la base de datos

# %%
df.Tipo.unique()
# Out:
# array(['Cocineta', 'Casa', 'Departamento', 'Casa de Condominio',
#        'Departamento en Hotel', 'Casa de Vecindad', 'Loft', 'Rancho',
#        'Posada/Chalé', 'Estudio'], dtype=object)

# %%
##value counts sirve para contar cuanto tengo de cada cosa
df.Tipo.value_counts()
# Out:
# Tipo
# Departamento             14764
# Cocineta                   726
# Casa de Condominio         610
# Casa                       545
# Departamento en Hotel      455
# Casa de Vecindad           158
# Loft                        38
# Rancho                       8
# Estudio                      4
# Posada/Chalé                 1
# Name: count, dtype: int64

# %%
## lo que hicimos en esta celda es sacar el porcentaje de cada uno con respecto del total
df.Tipo.value_counts(normalize=True)
# Out:
# Tipo
# Departamento             0.852967
# Cocineta                 0.041943
# Casa de Condominio       0.035242
# Casa                     0.031487
# Departamento en Hotel    0.026287
# Casa de Vecindad         0.009128
# Loft                     0.002195
# Rancho                   0.000462
# Estudio                  0.000231
# Posada/Chalé             0.000058
# Name: proportion, dtype: float64

# %%
porcentaje_tipo= df.Tipo.value_counts(normalize=True).to_frame()
porcentaje_tipo.plot(kind="bar",figsize=(12,8), color="green", xlabel="Tipos", ylabel="Porcentajes" )
# Out:
# <Axes: xlabel='Tipos', ylabel='Porcentajes'>

# %%
df.query("Tipo == 'Departamento'")
# Out:
#                Tipo               Colonia  Habitaciones  Garages  Suites  \
# 3      Departamento      Centro Histórico             1        0       0
# 4      Departamento             Del Valle             1        0       0
# 7      Departamento      Centro Histórico             1        0       0
# 8      Departamento               Condesa             1        0       1
# 10     Departamento               Condesa             4        3       1
# ...             ...                   ...           ...      ...     ...
# 25111  Departamento  Lomas de Chapultepec             3        0       1
# 25113  Departamento              Coyoacán             3        1       2
# 25114  Departamento              Narvarte             1        0       0
# 25118  Departamento               Mixcoac             2        1       0
# 25119  Departamento  Lomas de Chapultepec             2        0       0
#
#        Area    Valor  Condominio  Impuesto
# 3        15   2800.0      1365.0      70.0
# 4        48   2800.0       805.0       NaN
# 7        36   4200.0         NaN       NaN
# 8        40   7000.0      1963.5     175.0
# 10      243  45500.0      7000.0    2810.5
# ...     ...      ...         ...       ...
# 25111    80  10500.0      3535.0     871.5
# 25113   150  52500.0      4900.0    2100.0
# 25114    28   3500.0      1260.0      87.5
# 25118    48   4900.0      1781.5     129.5
# 25119    70  10500.0      2660.0       NaN
#
# [14764 rows x 9 columns]

# %%
df=df.query("Tipo == 'Departamento'")
df.head(2)
# Out:
#            Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 3  Departamento  Centro Histórico             1        0       0    15
# 4  Departamento         Del Valle             1        0       0    48
#
#     Valor  Condominio  Impuesto
# 3  2800.0      1365.0      70.0
# 4  2800.0       805.0       NaN

# %%
df.shape
# Out:
# (14764, 9)

# %% [markdown]
# ###**TRATAMIENTO DE DATOS NULOS**

# %%
#esta no es la mejor manera para visualizar valores nulos, true= existen valores nulos
df.isnull()
# Out:
#         Tipo  Colonia  Habitaciones  Garages  Suites   Area  Valor  \
# 3      False    False         False    False   False  False  False
# 4      False    False         False    False   False  False  False
# 7      False    False         False    False   False  False  False
# 8      False    False         False    False   False  False  False
# 10     False    False         False    False   False  False  False
# ...      ...      ...           ...      ...     ...    ...    ...
# 25111  False    False         False    False   False  False  False
# 25113  False    False         False    False   False  False  False
# 25114  False    False         False    False   False  False  False
# 25118  False    False         False    False   False  False  False
# 25119  False    False         False    False   False  False  False
#
#        Condominio  Impuesto
# 3           False     False
# 4           False      True
# 7            True      True
# 8           False     False
# 10          False     False
# ...           ...       ...
# 25111       False     False
# 25113       False     False
# 25114       False     False
# 25118       False     False
# 25119       False      True
#
# [14764 rows x 9 columns]

# %%
#esta si es la meor manera para visualizar si existen valores nulos, y con esta funcion te suma los valores nulos existentes por columna
df.isnull().sum()
# Out:
# Tipo               0
# Colonia            0
# Habitaciones       0
# Garages            0
# Suites             0
# Area               0
# Valor              7
# Condominio       493
# Impuesto        3797
# dtype: int64

# %%
#en este paso vamos a rellenar o sustituir los valores nulos por un 0
df.fillna(0)
# Out:
#                Tipo               Colonia  Habitaciones  Garages  Suites  \
# 3      Departamento      Centro Histórico             1        0       0
# 4      Departamento             Del Valle             1        0       0
# 7      Departamento      Centro Histórico             1        0       0
# 8      Departamento               Condesa             1        0       1
# 10     Departamento               Condesa             4        3       1
# ...             ...                   ...           ...      ...     ...
# 25111  Departamento  Lomas de Chapultepec             3        0       1
# 25113  Departamento              Coyoacán             3        1       2
# 25114  Departamento              Narvarte             1        0       0
# 25118  Departamento               Mixcoac             2        1       0
# 25119  Departamento  Lomas de Chapultepec             2        0       0
#
#        Area    Valor  Condominio  Impuesto
# 3        15   2800.0      1365.0      70.0
# 4        48   2800.0       805.0       0.0
# 7        36   4200.0         0.0       0.0
# 8        40   7000.0      1963.5     175.0
# 10      243  45500.0      7000.0    2810.5
# ...     ...      ...         ...       ...
# 25111    80  10500.0      3535.0     871.5
# 25113   150  52500.0      4900.0    2100.0
# 25114    28   3500.0      1260.0      87.5
# 25118    48   4900.0      1781.5     129.5
# 25119    70  10500.0      2660.0       0.0
#
# [14764 rows x 9 columns]

# %%
#ESTE PASO ES PARA TRATAR LOS DATOS NULOS
#primero lo asignamos a nuestra variable df para guardarla y despues lo mostramos para que aparezcan puros valores nulos (ceros) con .sum
df=df.fillna(0)
df.isnull().sum()
# Out:
# Tipo            0
# Colonia         0
# Habitaciones    0
# Garages         0
# Suites          0
# Area            0
# Valor           0
# Condominio      0
# Impuesto        0
# dtype: int64

# %% [markdown]
# ###**REMOVER REGRISTROS INCONSISTENTES**

# %%
#con query me devuelve las filas y columnas en las que exista algun valor nulo(ceros) o registros inconsistentes
df.query("Valor == 0 | Condominio == 0")
# Out:
#                Tipo                 Colonia  Habitaciones  Garages  Suites  \
# 7      Departamento        Centro Histórico             1        0       0
# 49     Departamento                Santa Fe             2        1       1
# 74     Departamento  Ciudad de los Deportes             2        0       0
# 116    Departamento              El Rosedal             2        1       0
# 136    Departamento                Santa Fe             1        1       1
# ...             ...                     ...           ...      ...     ...
# 24721  Departamento                Doctores             2        0       0
# 24736  Departamento                 Condesa             1        0       0
# 24866  Departamento                 Condesa             3        0       0
# 24892  Departamento             Loma Bonita             1        0       0
# 25014  Departamento           Culhuacán CTM             3        0       1
#
#        Area    Valor  Condominio  Impuesto
# 7        36   4200.0         0.0       0.0
# 49       70      0.0      3395.0     238.0
# 74       80   3500.0         0.0       0.0
# 116      50   3850.0         0.0       0.0
# 136      65   8225.0         0.0       0.0
# ...     ...      ...         ...       ...
# 24721    43   3150.0         0.0      56.0
# 24736    30   9100.0         0.0       0.0
# 24866   130  16100.0         0.0       0.0
# 24892    40   1925.0         0.0       0.0
# 25014    70   4200.0         0.0       0.0
#
# [500 rows x 9 columns]

# %%
#aqui usamos .index para saver el numero del registro que se encuentra a la izquierda de la tabla de arriba
df.query("Valor == 0 | Condominio == 0").index
# Out:
# Index([    7,    49,    74,   116,   136,   185,   199,   432,   504,   527,
#        ...
#        24426, 24555, 24563, 24597, 24671, 24721, 24736, 24866, 24892, 25014],
#       dtype='int64', length=500)

# %%
#aqui estamos creando un filtro y  asignando nuestro index a una variable llamada remover
df_remover = df.query("Valor == 0 | Condominio == 0").index

# %%
#drop es para remover y dentro de el parentesis indicamos lo que queremos remover,  axis=0 son las filas
df.drop(df_remover, axis= 0,  inplace=True)

# %%
#volviendo a consultar nuestro query, vemos que ya no nos muestra nada porque ya no hay valores nulos o registros inconsistentes en existencia
df.query("Valor == 0 | Condominio == 0").index
# Out:
# Index([], dtype='int64')

# %%
df.head()
# Out:
#             Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 3   Departamento  Centro Histórico             1        0       0    15
# 4   Departamento         Del Valle             1        0       0    48
# 8   Departamento           Condesa             1        0       1    40
# 10  Departamento           Condesa             4        3       1   243
# 13  Departamento          Santa Fe             2        1       1    67
#
#       Valor  Condominio  Impuesto
# 3    2800.0      1365.0      70.0
# 4    2800.0       805.0       0.0
# 8    7000.0      1963.5     175.0
# 10  45500.0      7000.0    2810.5
# 13   5950.0      2061.5     514.5

# %%
df.Tipo.unique()
# Out:
# array(['Departamento'], dtype=object)

# %%
df.drop("Tipo", axis=1, inplace=True)
df.sample(10)
# Out:
#                     Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 21503              Santa Fe             4        4       2   237  24325.0
# 10760              Santa Fe             5        4       5   434  70000.0
# 13341              Coyoacán             2        2       0   110  14700.0
# 5274              Del Valle             5        2       1   367  21000.0
# 3443               Santa Fe             2        2       1    78   7000.0
# 7384                Condesa             3        1       0   110  12250.0
# 8624                Condesa             1        0       0    40   5950.0
# 6446   Lomas de Chapultepec             2        1       0    82  12250.0
# 10406                  Roma             3        1       1   110   9800.0
# 19566               Condesa             3        0       0   110  11550.0
#
#        Condominio  Impuesto
# 21503     12397.0    1981.0
# 10760     16100.0   38500.0
# 13341      5250.0     875.0
# 5274       7035.0       0.0
# 3443      10899.0    1417.5
# 7384       3181.5     581.0
# 8624       1575.0       0.0
# 6446       3920.0       0.0
# 10406      3500.0       0.0
# 19566      2800.0     455.0

# %% [markdown]
# ###**CREANDO FILTROS**

# %% [markdown]
# ####**1.-Apartamentos que tienen 1 dormitorio y un alquiler menor a MXN 4200.**

# %%
#hacemos el primer filtro llamado seleccion1 y en el se encuentran las habitaciones que tengan 1 dormitorio
seleccion1 =df["Habitaciones"]==1

# %%
type(seleccion1)
# Out:
# pandas.core.series.Series

# %%
#mostramos el data frame para observar que la columna de habitaciones tiene 1 dormitorio
df[seleccion1]
# Out:
#                     Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 3          Centro Histórico             1        0       0    15   2800.0
# 4                 Del Valle             1        0       0    48   2800.0
# 8                   Condesa             1        0       1    40   7000.0
# 19                 Narvarte             1        0       0    48   2625.0
# 37         Centro Histórico             1        0       0    27   2625.0
# ...                     ...           ...      ...     ...   ...      ...
# 25090              Coyoacán             1        0       0    55   7000.0
# 25092              Santa Fe             1        1       0    62   5950.0
# 25100  Lomas de Chapultepec             1        1       1    50  15050.0
# 25103               Condesa             1        0       0    50   6825.0
# 25114              Narvarte             1        0       0    28   3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# 4           805.0       0.0
# 8          1963.5     175.0
# 19         2702.0      87.5
# 37         1298.5      66.5
# ...           ...       ...
# 25090      2205.0      66.5
# 25092      3307.5     630.0
# 25100      6055.0     906.5
# 25103      1575.0     245.0
# 25114      1260.0      87.5
#
# [2072 rows x 8 columns]

# %%
#creamos el filtro 2 llamado seleccion2 y aqui estamos mostrando las habitaciones que tienen 1 dormitorio y que cuestan menos de 4200
seleccion2=df["Valor"]<4200
df[seleccion2]
# Out:
#                   Colonia  Habitaciones  Garages  Suites  Area   Valor  \
# 3        Centro Histórico             1        0       0    15  2800.0
# 4               Del Valle             1        0       0    48  2800.0
# 19               Narvarte             1        0       0    48  2625.0
# 37       Centro Histórico             1        0       0    27  2625.0
# 61       Centro Histórico             1        1       0    37  3850.0
# ...                   ...           ...      ...     ...   ...     ...
# 25038  Villa de Guadalupe             2        1       0    50  2800.0
# 25051           Nativitas             2        1       0    62  3500.0
# 25065           Nativitas             2        1       0    50  3150.0
# 25095      Lindavista Sur             2        0       0    63  2800.0
# 25114            Narvarte             1        0       0    28  3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# 4           805.0       0.0
# 19         2702.0      87.5
# 37         1298.5      66.5
# 61         1890.0    3150.0
# ...           ...       ...
# 25038      1435.0       0.0
# 25051      1050.0       0.0
# 25065      1050.0       0.0
# 25095      1372.0       0.0
# 25114      1260.0      87.5
#
# [1013 rows x 8 columns]

# %%
#aqui usamos el .max para que nos muestre la habitacion mas cara en nuestra seleccion2 y observamos que el valor mas caro es de 4025 MXN
df[seleccion2].max()
# Out:
# Colonia         Álvaro Obregón
# Habitaciones                 3
# Garages                      2
# Suites                       2
# Area                       176
# Valor                   4025.0
# Condominio            152575.5
# Impuesto                6699.0
# dtype: object

# %%
#en esta celda estamos unificando criterios para poder cumplir con el filtro de que sea 1 dormitorio por habitacion y cueste menos de 4200 MXN
filtro1= (seleccion1) & (seleccion2)
df[filtro1]
# Out:
#                 Colonia  Habitaciones  Garages  Suites  Area   Valor  \
# 3      Centro Histórico             1        0       0    15  2800.0
# 4             Del Valle             1        0       0    48  2800.0
# 19             Narvarte             1        0       0    48  2625.0
# 37     Centro Histórico             1        0       0    27  2625.0
# 61     Centro Histórico             1        1       0    37  3850.0
# ...                 ...           ...      ...     ...   ...     ...
# 24710         Nativitas             1        0       0    40  3150.0
# 24872        Peralvillo             1        0       1    69  3150.0
# 24880        La Condesa             1        0       0    46  3850.0
# 24943              Roma             1        0       0    21  3500.0
# 25114          Narvarte             1        0       0    28  3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# 4           805.0       0.0
# 19         2702.0      87.5
# 37         1298.5      66.5
# 61         1890.0    3150.0
# ...           ...       ...
# 24710      1522.5       0.0
# 24872      2240.0     441.0
# 24880      1585.5     112.0
# 24943       987.0      87.5
# 25114      1260.0      87.5
#
# [361 rows x 8 columns]

# %%
df1= df[filtro1]

# %% [markdown]
# ####**2.-Apartamentos que tienen al menos 2 dormitorios, un alquiler menor a MXN 10500 y una superficie mayor a 70 m².**

# %%
filtro2= (df["Habitaciones"]>=2) & (df["Valor"] < 10500) & (df["Area"]>70 )
df[filtro2]
# Out:
#          Colonia  Habitaciones  Garages  Suites  Area   Valor  Condominio  \
# 14      Narvarte             2        1       0   110  6650.0      2450.0
# 16      Narvarte             2        1       0    78  7000.0      2450.0
# 21          Roma             2        1       0    76  8750.0      2590.0
# 33      Santa Fe             3        1       1    72  8225.0      2100.0
# 58      Santa Fe             3        2       1   104  9100.0      4774.0
# ...          ...           ...      ...     ...   ...     ...         ...
# 25028  Del Valle             2        0       1    90  7700.0      1890.0
# 25062   Santa Fe             2        1       1    72  5950.0      3045.0
# 25063   Narvarte             3        1       0    75  6650.0      3010.0
# 25105   Santa Fe             2        1       1    85  7875.0      5463.5
# 25106   Santa Fe             3        2       0    98  8050.0      3104.5
#
#        Impuesto
# 14        483.0
# 16          0.0
# 21          0.0
# 33        245.0
# 58       1421.0
# ...         ...
# 25028     483.0
# 25062     560.0
# 25063     493.5
# 25105     689.5
# 25106     619.5
#
# [2643 rows x 8 columns]

# %%
df2=df[filtro2]

# %% [markdown]
# ###**GUARDANDO LOS ARCHIVOS**

# %%
#le dimos un nuevo nombre al notebook(inmuebles_ml.csv) para poder verlo en el simbolo
# de carpeta que es para el DRIVE y asi reconocerlo
df.to_csv("inmuebles_ml.csv")

# %%
#vamos a leerlo con este comando para ver como quedó y muestra la columna del index que se habia eliminado como unnamed: 0
pd.read_csv("inmuebles_ml.csv")
# Out:
#        Unnamed: 0               Colonia  Habitaciones  Garages  Suites  Area  \
# 0               3      Centro Histórico             1        0       0    15
# 1               4             Del Valle             1        0       0    48
# 2               8               Condesa             1        0       1    40
# 3              10               Condesa             4        3       1   243
# 4              13              Santa Fe             2        1       1    67
# ...           ...                   ...           ...      ...     ...   ...
# 14259       25111  Lomas de Chapultepec             3        0       1    80
# 14260       25113              Coyoacán             3        1       2   150
# 14261       25114              Narvarte             1        0       0    28
# 14262       25118               Mixcoac             2        1       0    48
# 14263       25119  Lomas de Chapultepec             2        0       0    70
#
#          Valor  Condominio  Impuesto
# 0       2800.0      1365.0      70.0
# 1       2800.0       805.0       0.0
# 2       7000.0      1963.5     175.0
# 3      45500.0      7000.0    2810.5
# 4       5950.0      2061.5     514.5
# ...        ...         ...       ...
# 14259  10500.0      3535.0     871.5
# 14260  52500.0      4900.0    2100.0
# 14261   3500.0      1260.0      87.5
# 14262   4900.0      1781.5     129.5
# 14263  10500.0      2660.0       0.0
#
# [14264 rows x 9 columns]

# %%
#agregamos index=false para que nos quite la columna
df.to_csv("inmuebles_ml.csv", index=False)

# %%
#volvemos a leerlo usando pd.read_csv
pd.read_csv("inmuebles_ml.csv")
# Out:
#                     Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 0          Centro Histórico             1        0       0    15   2800.0
# 1                 Del Valle             1        0       0    48   2800.0
# 2                   Condesa             1        0       1    40   7000.0
# 3                   Condesa             4        3       1   243  45500.0
# 4                  Santa Fe             2        1       1    67   5950.0
# ...                     ...           ...      ...     ...   ...      ...
# 14259  Lomas de Chapultepec             3        0       1    80  10500.0
# 14260              Coyoacán             3        1       2   150  52500.0
# 14261              Narvarte             1        0       0    28   3500.0
# 14262               Mixcoac             2        1       0    48   4900.0
# 14263  Lomas de Chapultepec             2        0       0    70  10500.0
#
#        Condominio  Impuesto
# 0          1365.0      70.0
# 1           805.0       0.0
# 2          1963.5     175.0
# 3          7000.0    2810.5
# 4          2061.5     514.5
# ...           ...       ...
# 14259      3535.0     871.5
# 14260      4900.0    2100.0
# 14261      1260.0      87.5
# 14262      1781.5     129.5
# 14263      2660.0       0.0
#
# [14264 rows x 8 columns]

# %%
#para consistencia de los datos vamos a recrear el archivo porque lo esta guardando con coma y el archivo original es como punto y coma
df.to_csv("inmuebles_ml.csv", index=False, sep=";")

# %%
df1.to_csv("inmuebles_ml_filtro1.csv", index=False, sep=";")
df2.to_csv("inmuebles_ml_filtro2.csv", index=False, sep=";")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##**Demandas de DEV**

# %% [markdown]
# ###**Crear columnas numericas**

# %% [markdown]
# ####**1.-valor_mensual: Esta columna debe contener los gastos mensuales de cada propiedad, incluyendo el alquiler y el condominio.**

# %%
datos= pd.read_csv(url, sep=";")
datos
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 0           0    40   5950.0      1750.0     210.0
# 1           1   100  24500.0         NaN       NaN
# 2           0   150  18200.0     14070.0    3888.5
# 3           0    15   2800.0      1365.0      70.0
# 4           0    48   2800.0       805.0       NaN
# ...       ...   ...      ...         ...       ...
# 25116       0   755  49000.0         NaN       NaN
# 25117       0    27   2800.0      1225.0      87.5
# 25118       0    48   4900.0      1781.5     129.5
# 25119       0    70  10500.0      2660.0       NaN
# 25120       0   250  22750.0     14721.0    3881.5
#
# [25121 rows x 9 columns]

# %%
#CREACION de una columna adicional que se llama VALOR MENSUAL
datos["Valor_mensual"] = datos["Valor"] + datos["Condominio"]
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto  Valor_mensual
# 0    40   5950.0      1750.0     210.0         7700.0
# 1   100  24500.0         NaN       NaN            NaN
# 2   150  18200.0     14070.0    3888.5        32270.0
# 3    15   2800.0      1365.0      70.0         4165.0
# 4    48   2800.0       805.0       NaN         3605.0

# %% [markdown]
# ####**2.-valor_anual: Esta columna debe contener los gastos anuales por propiedad, es decir, el Impuesto más 12 meses de alquiler y condominio.**

# %%
datos["Valor_anual"]= datos["Valor_mensual"]*12 + datos["Impuesto"]
datos.tail()
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto  Valor_mensual  Valor_anual
# 25116       0   755  49000.0         NaN       NaN            NaN          NaN
# 25117       0    27   2800.0      1225.0      87.5         4025.0      48387.5
# 25118       0    48   4900.0      1781.5     129.5         6681.5      80307.5
# 25119       0    70  10500.0      2660.0       NaN        13160.0          NaN
# 25120       0   250  22750.0     14721.0    3881.5        37471.0     453533.5

# %% [markdown]
# ###**Crear columnas categoricas**

# %% [markdown]
# ####Descripcion: Esta columna debe contener un resumen de la información clave de las propiedades que se mostrarán en el sitio web: tipo de propiedad, barrio, cantidad de habitaciones y plazas de estacionamiento.

# %%
#   NO SE PUEDE CONCATENAR si hay valores int y str, los valores enteros van en habitaciones y garages
#           datos["Descripcion"] = datos["Tipo"] + " en " + datos["Colonia"] + \
#            " con " + datos["Habitaciones"] + "cuartos  y " +\
#            datos["Garages"] + " plazas de estacionamiento"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     217     try:
# --> 218         result = func(left, right)
#     219     except TypeError:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     241             # error: "None" not callable
# --> 242             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243     return _evaluate_standard(op, op_str, a, b)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     130     if result is None:
# --> 131         result = _evaluate_standard(op, op_str, a, b)
#     132
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b)
#      72         _store_test_result(False)
# ---> 73     return op(a, b)
#      74
#
# TypeError: can only concatenate str (not "int") to str
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-179-27924b0e7dd0> in <cell line: 0>()
#       1 #NO SE PUEDE CONCATENAR si hay valores int y str, los valores enteros van en habitaciones y garages
# ----> 2 datos["Descripcion"] = datos["Tipo"] + " en " + datos["Colonia"] + \
#       3             " con " + datos["Habitaciones"] + "cuartos  y " +\
#       4             datos["Garages"] + " plazas de estacionamiento"
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#      77
#      78     return new_method
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/arraylike.py in __add__(self, other)
#     184         moose     3.0     NaN
#     185         """
# --> 186         return self._arith_method(other, operator.add)
#     187
#     188     @unpack_zerodim_and_defer("__radd__")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in _arith_method(self, other, op)
#    6133     def _arith_method(self, other, op):
#    6134         self, other = self._align_for_op(other)
# -> 6135         return base.IndexOpsMixin._arith_method(self, other, op)
#    6136
#    6137     def _align_for_op(self, right, align_asobject: bool = False):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/base.py in _arith_method(self, other, op)
#    1380
#    1381         with np.errstate(all="ignore"):
# -> 1382             result = ops.arithmetic_op(lvalues, rvalues, op)
#    1383
#    1384         return self._construct_result(result, name=res_name)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/ops/array_ops.py in arithmetic_op(left, right, op)
#     281         # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     282         # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 283         res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     284
#     285     return res_values
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     225             # Don't do this for comparisons, as that will handle complex numbers
#     226             #  incorrectly, see GH#32047
# --> 227             result = _masked_arith_op(left, right, op)
#     228         else:
#     229             raise
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/ops/array_ops.py in _masked_arith_op(x, y, op)
#     161         # See GH#5284, GH#5035, GH#19448 for historical reference
#     162         if mask.any():
# --> 163             result[mask] = op(xrav[mask], yrav[mask])
#     164
#     165     else:
#
# TypeError: can only concatenate str (not "int") to str

# %%
# se usa .astype(str) para poder concatenar sin problemas y lo usaremos en habitaciones y garages
datos["Descripcion"] = datos["Tipo"] + " en la colonia " + datos["Colonia"] + \
             " con " + datos["Habitaciones"].astype(str) + "cuartos  y " +\
             datos["Garages"].astype(str) + " plazas de estacionamiento"

# %%
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto  Valor_mensual  Valor_anual  \
# 0    40   5950.0      1750.0     210.0         7700.0      92610.0
# 1   100  24500.0         NaN       NaN            NaN          NaN
# 2   150  18200.0     14070.0    3888.5        32270.0     391128.5
# 3    15   2800.0      1365.0      70.0         4165.0      50050.0
# 4    48   2800.0       805.0       NaN         3605.0          NaN
#
#                                          Descripcion
# 0  Cocineta en la colonia Condesa con 1cuartos  y...
# 1  Casa en la colonia Polanco con 2cuartos  y 0 p...
# 2  Conjunto Comercial/Sala en la colonia Santa Fe...
# 3  Departamento en la colonia Centro Histórico co...
# 4  Departamento en la colonia Del Valle con 1cuar...

# %%
datos.iloc[500].Descripcion
# Out:
# 'Departamento en la colonia Napoles con 1cuartos  y 0 plazas de estacionamiento'

# %% [markdown]
# ####Tiene_suite: Esta debe ser una columna que indique únicamente si la propiedad tiene o no suites, sin importar la cantidad.

# %%
datos["Tiene_suite"]= datos["Suites"].apply(lambda x: "Si" if x > 0 else "No")

# %%
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto  Valor_mensual  Valor_anual  \
# 0    40   5950.0      1750.0     210.0         7700.0      92610.0
# 1   100  24500.0         NaN       NaN            NaN          NaN
# 2   150  18200.0     14070.0    3888.5        32270.0     391128.5
# 3    15   2800.0      1365.0      70.0         4165.0      50050.0
# 4    48   2800.0       805.0       NaN         3605.0          NaN
#
#                                          Descripcion Tiene_suite
# 0  Cocineta en la colonia Condesa con 1cuartos  y...          No
# 1  Casa en la colonia Polanco con 2cuartos  y 0 p...          Si
# 2  Conjunto Comercial/Sala en la colonia Santa Fe...          No
# 3  Departamento en la colonia Centro Histórico co...          No
# 4  Departamento en la colonia Del Valle con 1cuar...          No

# %%
datos.to_csv("/content/drive/MyDrive/Colab Notebooks/inmuebles_dev.csv", index= False, sep=";")

# %% [markdown]
# #**PRIMER EJERCICIO**

# %% [markdown]
# Para practicar los métodos aprendidos a lo largo de esta lección y aprender nuevos, realizaremos algunos análisis utilizando un archivo CSV diferente: **alumnos.csv.**
#
# URL= "https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv"
#
#
# 1.-Importa el archivo **alumnos.csv** y almacena su contenido en un DataFrame de Pandas.
#
# 2.-Visualiza las primeras 7 filas del DataFrame y las últimas 5.
#
# 3.-Verifica la cantidad de filas y columnas en este DataFrame.
#
# 4.-Explora las columnas del DataFrame y analiza los tipos de datos presentes en cada columna.
#
#
#
# Extra: Calcula algunas estadísticas descriptivas básicas de los datos en el DataFrame (media, desviación estándar, etc.). Pista: busca el método "describe".
#
# Si necesitas ayuda, en la sección "Opinión del Instructor" puedes encontrar algunas formas de resolver los desafíos propuestos anteriormente.

# %%
##Para importar el archivo en cuestión y guardarlo en un DataFrame, podemos importar la biblioteca Pandas
##y utilizar la función read_csv() pasando la URL donde se encuentra el archivo:

# %%
import pandas as pd
url = "https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv"
datos = pd.read_csv(url)

# %%
##Cuando queremos ver las primeras y últimas filas de un DataFrame, podemos utilizar los métodos head y tail:
datos.head(7)
datos.tail(5)
# Out:
#     Nombre  Edad  Nota   Aprobado
# 13  Miriam    25   9.0       True
# 14   Pablo    37   NaN      False
# 15  Milena    29   7.0       True
# 16   Lucas    33   NaN      False
# 17   Nadia    34   8.0  Verdadero

# %%
##Tanto el atributo shape como el método info nos proporcionan la cantidad de filas y columnas en un DataFrame.
##El info también muestra información adicional, por lo que utilizaremos shape aquí:
datos.shape
# Out:
# (18, 4)

# %%
##En este momento, podemos usar .columns para ver las columnas presentes en el DataFrame.
##Además, también podemos seleccionar columnas específicas utilizando corchetes "[]".
##Para ver los tipos de datos en cada columna, esta vez opté por utilizar un atributo llamado dtypes:

# Visualizar los nombres de las columnas
datos.columns

# Seleccionar una columna
datos['Nombre']

# Seleccionar múltiples columnas
datos[['Edad', 'Nota']]

# Verificar los tipos de datos en cada columna
datos.dtypes
# Out:
# Nombre       object
# Edad          int64
# Nota        float64
# Aprobado     object
# dtype: object

# %%
##Extra: Como la sugerencia misma mencionó, podemos utilizar un método de Pandas llamado describe
##para calcular algunas estadísticas descriptivas básicas de los datos en el DataFrame:

datos.describe()

#El método describe() es una de las funciones más útiles de Pandas para el análisis exploratorio de datos.
#Se utiliza para calcular algunas estadísticas descriptivas básicas de los datos en un DataFrame o en una columna específica de un DataFrame.
# Out:
#             Edad       Nota
# count  18.000000  12.000000
# mean   25.500000   6.841667
# std     6.070662   2.264532
# min    18.000000   2.500000
# 25%    21.000000   5.450000
# 50%    24.500000   7.000000
# 75%    28.750000   8.250000
# max    37.000000  10.000000

# %% [markdown]
# #**SEGUNDO EJERCICIO**

# %% [markdown]
# El equipo de ML ha llegado con algunas demandas de última hora que debemos resolver en este momento de análisis exploratorio. Estas demandas son las siguientes:
#
# 1.-Calcular el promedio de habitaciones por departamento.
#
# 2.-Verificar cuántas colonias únicas existen en nuestra base de datos.
#
# 3.-Analizar qué colonias tienen el promedio de alquiler más alto.
#
# 4.-Crear un gráfico de barras horizontales que muestre las 5 colonias con los promedios de alquiler más altos.

# %% [markdown]
# Es importante destacar que en algunas situaciones podemos utilizar diferentes métodos de Pandas para lograr lo mismo. Por lo tanto, las soluciones a continuación no son la única forma de abordar los desafíos planteados.
#
# 1 - Para calcular el promedio de habitaciones, podemos seleccionar la columna de interés y aplicar el método mean():

# %%
df['Habitaciones'].mean()
# Out:
# np.float64(2.519139091418957)

# %% [markdown]
# 2 - Una forma de verificar cuántos barrios únicos existen en la base de datos sería utilizando el método unique(), que nos devolverá una lista con los barrios únicos. Luego, podemos usar la función len para contar cuántos elementos hay en esa lista:

# %%
len(df['Colonia'].unique())
# Out:
# 80

# %% [markdown]
# Además, también podemos utilizar un método de Pandas que realiza directamente el conteo de elementos únicos en una columna específica. Este método es nunique():

# %%
df['Colonia'].nunique()
# Out:
# 80

# %% [markdown]
# 3 - Para analizar qué barrios tienen el promedio de valor de alquiler más alto, podemos:
#
# Agrupar nuestra base de datos por la columna "Colonia".
#
# Aplicar el método mean.
#
# Colocar el resultado en un DataFrame y ordenarlo.

# %%
##El parámetro ascending=False se utiliza en la función sort_values() para ordenar los valores en orden descendente (de mayor a menor).
df.groupby('Colonia')[['Valor']].mean().sort_values('Valor', ascending=False)
# Out:
#                                Valor
# Colonia
# Los Alpes               54250.000000
# Bosques de Aragón       36828.633333
# Coyoacán                33128.106236
# Roma                    32969.959512
# Lomas de Chapultepec    30184.527005
# ...                              ...
# El Rodeo                 2275.000000
# Santa Marta Acatitla     2244.375000
# Santa María Nonoalco     2100.000000
# San Antonio Tecomitl     2065.000000
# Santa María Aztahuacán   1785.000000
#
# [80 rows x 1 columns]

# %% [markdown]
# 4 - Como queremos crear un gráfico con solo las 5 colonias que tienen el promedio de alquiler más alto, podemos usar .head() para seleccionar las 5 primeras filas del DataFrame que creamos en el desafío 3 y guardar eso en una variable:

# %%
df_colonias = df.groupby('Colonia')[['Valor']].mean().sort_values('Valor', ascending=False).head()

# %% [markdown]
# Luego, podemos crear el gráfico:

# %%
df_colonias.plot(kind='barh', figsize=(14,10), color='blue');

# %% [markdown]
# #**TERCER EJERCICIO**

# %% [markdown]
# El método drop() de la biblioteca Pandas permite eliminar una o más filas y/o columnas de un DataFrame. Esta eliminación se puede realizar de forma permanente en el DataFrame original. Es posible especificar los índices de las filas y/o columnas que se deben eliminar, así como el eje en el que debe ocurrir la eliminación.
#
# Suponga que tenemos el siguiente DataFrame, guardado en una variable llamada "datos":

# %%
import pandas as pd

datos = pd.DataFrame([['Plaza', 'Cebolla', 2.5],
                      ['Mercado', 'Cebolla', 1.99],
                      ['Supermercado', 'Cebolla', 1.69],
                      ['Plaza', 'Tomate', 4],
                      ['Mercado', 'Tomate', 3.29],
                      ['Supermercado', 'Tomate', 2.99],
                      ['Plaza', 'Papa', 4.2],
                      ['Mercado', 'Papa', 3.99],
                      ['Supermercado', 'Papa', 3.69]],
                      columns = ['Comercio', 'Producto', 'Precio'])

# %% [markdown]
# **¿Cuál de los siguientes códigos se podría utilizar para eliminar de forma permanente las filas en las que,
# en la columna "Comercio", tenemos "Supermercado"?**

# %%
datos.drop([2, 5, 8], axis=0, inplace=True)

# %% [markdown]
# #**CUARTO EJERCICIO**

# %% [markdown]
# El equipo de Machine Learning solicitó realizar otro filtro en nuestra base de datos. Esta vez, el filtro sería para obtener la siguiente información:
#
# ¿Cuáles son los apartamentos que tienen un área mayor de 80 m² o un alquiler menor de MXN 4.000,00?
#
# Con base en esto, ¿cuál de las siguientes opciones presenta un código que se puede utilizar para obtener la información solicitada?

# %%
seleccion = (df['Area'] > 80) | (df['Valor'] < 4000)
df[seleccion]
# Out:
#                 Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 3      Centro Histórico             1        0       0    15   2800.0
# 4             Del Valle             1        0       0    48   2800.0
# 10              Condesa             4        3       1   243  45500.0
# 14             Narvarte             2        1       0   110   6650.0
# 18             Coyoacán             3        1       1   125  24500.0
# ...                 ...           ...      ...     ...   ...      ...
# 25105          Santa Fe             2        1       1    85   7875.0
# 25106          Santa Fe             3        2       0    98   8050.0
# 25108          Santa Fe             3        2       2   140  19250.0
# 25113          Coyoacán             3        1       2   150  52500.0
# 25114          Narvarte             1        0       0    28   3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# 4           805.0       0.0
# 10         7000.0    2810.5
# 14         2450.0     483.0
# 18         7350.0    1620.5
# ...           ...       ...
# 25105      5463.5     689.5
# 25106      3104.5     619.5
# 25108      6650.0    2450.0
# 25113      4900.0    2100.0
# 25114      1260.0      87.5
#
# [9601 rows x 8 columns]

# %% [markdown]
# #**QUINTO EJERCICIO**

# %% [markdown]
# 1.-Verifica si la base de datos contiene datos nulos y, en caso de tenerlos, realiza el tratamiento de estos datos nulos de la manera que consideres más coherente con la situación.
#
# 2.-Los estudiantes "Alicia" y "Carlos" ya no forman parte del grupo. Por lo tanto, elimínalos de la base de datos.
#
# 3.-Aplica un filtro que seleccione solo a los estudiantes que fueron aprobados.
#
# 4.-Guarda el DataFrame que contiene solo a los estudiantes aprobados en un archivo CSV llamado "alumnos_aprobados.csv".
#
# Extra: Al revisar las calificaciones de los estudiantes aprobados, notamos que algunas calificaciones eran incorrectas. Las estudiantes que obtuvieron una calificación de 7.0, en realidad tenían un punto extra que no se contabilizó. Por lo tanto, reemplaza las calificaciones de 7.0 en la base de datos por 8.0. Consejo: busca el método replace.

# %%
url="https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv"
datos = pd.read_csv(url)
datos
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   NaN      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   NaN      False
# 6    Daniela    21   7.0       True
# 7     Carlos    19   6.0      False
# 8     Alicia    35   5.6      False
# 9     Victor    28   NaN      False
# 10    Danilo    21   NaN      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   NaN      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   NaN      False
# 17     Nadia    34   8.0  Verdadero

# %% [markdown]
# 1 - Podemos comenzar verificando la existencia de datos nulos:

# %%
datos.isnull().sum()
# Out:
# Nombre      0
# Edad        0
# Nota        6
# Aprobado    0
# dtype: int64

# %% [markdown]
# Con el resultado, notaremos que solo la columna "Nota" contiene datos nulos. En este caso, podemos suponer que los estudiantes sin calificación probablemente tenían un 0. Por lo tanto, podemos reemplazar los valores nulos por 0:

# %%
datos = datos.fillna(0)
datos
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   0.0      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   0.0      False
# 6    Daniela    21   7.0       True
# 7     Carlos    19   6.0      False
# 8     Alicia    35   5.6      False
# 9     Victor    28   0.0      False
# 10    Danilo    21   0.0      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   0.0      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   0.0      False
# 17     Nadia    34   8.0  Verdadero

# %% [markdown]
# 2 - Para eliminar a los estudiantes "Alicia" y "Carlos" de nuestra base de datos, necesitamos obtener los índices de las filas donde se encuentran sus nombres y utilizar el método drop para eliminar las filas respectivas:

# %%
# Guardamos los índices de las filas a eliminar en una variable
alumnos_a_eliminar = datos.query('Nombre == "Alicia" | Nombre == "Carlos"').index

# Eliminamos las filas correspondientes a los estudiantes "Alicia" y "Carlos"
datos.drop(alumnos_a_eliminar, axis=0, inplace=True)

# %% [markdown]
# 3 - En este caso, nuestro primer paso es crear una variable en la que seleccionamos solo a los estudiantes aprobados:

# %%
seleccion = datos['Aprobado'] == True

# %% [markdown]
# Hecho esto, podemos aplicar esta selección a nuestro DataFrame:

# %%
datos[seleccion]
# Out:
# Empty DataFrame
# Columns: [Nombre, Edad, Nota, Aprobado]
# Index: []

# %% [markdown]
# 4 - Para guardar el DataFrame con solo los estudiantes aprobados, podemos comenzar guardando el DataFrame resultante del desafío 3 en una variable:

# %%
alumnos_aprobados = datos[seleccion]

# %% [markdown]
# Luego, podemos usar el método to_csv para guardarlo en formato CSV:

# %%
alumnos_aprobados.to_csv('alumnos_aprobados.csv', index=False)

# %% [markdown]
# Extra: El método replace se utiliza para reemplazar un valor específico por otro. En el caso de nuestra base de datos, queremos reemplazar los valores 7.0 por 8.0. Para hacerlo, podemos usar el siguiente fragmento de código:

# %%
alumnos_aprobados.replace(7.0, 8.0)
# Out:
# Empty DataFrame
# Columns: [Nombre, Edad, Nota, Aprobado]
# Index: []

# %% [markdown]
# Y para guardar este cambio de forma definitiva, podemos asignarlo a nuestra variable:

# %%
alumnos_aprobados = alumnos_aprobados.replace(7.0, 8.0)

# %% [markdown]
# #**SEXTO EJERCICIO**

# %%
import pandas as pd

datos = {
    'Nombre': ['Jetta', 'Passat', 'Crossfox', 'DS5', 'Escarabajo'],
    'Motor': ['Motor 4.0 Turbo', 'Motor Diesel', 'Motor Diesel V8', 'Motor 2.0', 'Motor 1.6'],
    'Modelo': [2019, 2003, 1991, 2019, 1990],
    'Kilometraje': [0.0, 5712.0, 37123.0, 0.0, 120000.0],
    'Valor': [88000.0, 106000.0, 72000.0, 89000.0, 32000.0],
    'Impuesto': [2000.0, 5000.0, 1700.0, 2200.0, 1000.0],
    'Descuento': [380.0, 450.0, 277.0, 400.0, 150.0]
}

df = pd.DataFrame(datos)

# %%
df

# %% [markdown]
# Necesitamos crear una columna llamada "Valor_total" que tenga el valor del automóvil, sumado al impuesto y menos el valor del descuento. ¿Cuál de las siguientes opciones presenta el código correcto para crear esta columna?

# %%
df['Valor_total'] = df['Valor'] + df['Impuesto'] - df['Descuento']

# %%
df['Valor_total']

# %% [markdown]
# #**SEPTIMO EJERCICIO**

# %% [markdown]
# Hay varias formas de crear columnas en un DataFrame en Pandas. Algunos ejemplos son:
#
# 1 - Asignación directa de valores a una nueva columna:

# %%
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
df['C'] = [7, 8, 9]

# %% [markdown]
# 2 - Creación de una columna a partir de operaciones entre otras columnas:

# %%
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
df['C'] = df['A'] + df['B']

# %% [markdown]
# 3 - Uso del método assign() para crear una nueva columna:

# %%
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
df = df.assign(C=[7, 8, 9])

# %% [markdown]
# 4 - Uso del método apply() para aplicar una función a una columna existente y crear una nueva columna:

# %%
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
df['C'] = df['A'].apply(lambda x: x * 2)

# %% [markdown]
# #**OCTAVO EJERCICIO**

# %% [markdown]
# Para practicar los métodos aprendidos en esta lección y aprender nuevos, realizaremos algunos tratamientos y selecciones utilizando un archivo CSV diferente: alumnos.csv.
#
# Este archivo es el mismo que se utilizó para resolver los desafíos de las aulas 1 y 3 y contiene datos de estudiantes de un curso superior. Con base en esto, resolvamos los problemas propuestos a continuación utilizando los conocimientos adquiridos hasta ahora.
#
# Los estudiantes participaron en una actividad extracurricular y ganaron puntos extras. Estos puntos extras corresponden al 40% de su nota actual. Por lo tanto, crea una columna llamada "Puntos_extras" que contenga los puntos extras de cada estudiante, es decir, el 40% de su nota actual.
#
# Crea otra columna llamada "Notas_finales" que contenga las notas de cada estudiante sumadas con los puntos extras.
#
# Dado que hubo una puntuación extra, algunos estudiantes que no habían sido aprobados antes pueden haber sido aprobados ahora. En función de esto, crea una columna llamada "Aprobado_final" con los siguientes valores:
#
# True: si el estudiante está aprobado (la nota final debe ser mayor o igual a 7.0).
# False: si el estudiante está reprobado (la nota final debe ser menor que 7.0).
# Realiza una selección y verifica qué estudiantes no habían sido aprobados anteriormente, pero ahora fueron aprobados después de sumar los puntos extras.

# %%
url="https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv"
datos= pd.read_csv(url)
datos
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   NaN      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   NaN      False
# 6    Daniela    21   7.0       True
# 7     Carlos    19   6.0      False
# 8     Alicia    35   5.6      False
# 9     Victor    28   NaN      False
# 10    Danilo    21   NaN      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   NaN      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   NaN      False
# 17     Nadia    34   8.0  Verdadero

# %% [markdown]
# 1 - Para crear la columna "Puntos_extras", podemos utilizar el método apply para aplicar una función a la columna "Nota". Esta función debe multiplicar 0.4 por el valor de la nota de cada estudiante y colocar el resultado en nuestra nueva columna:

# %%
datos['Puntos_extras'] = datos['Nota'].apply(lambda x: x*0.4)

# %% [markdown]
# 2 - La columna "Notas_finales" será la suma de las columnas "Nota" y "Puntos_extras":

# %%
datos['Notas_finales'] = datos['Nota'] + datos['Puntos_extras']

# %% [markdown]
# 3 - Para crear la columna "Aprobado_final", podemos utilizar el método apply para aplicar una función a la columna "Notas_finales". Esta función debe colocar True si la nota final es mayor o igual a 7.0 y, en caso contrario, debe colocar False:

# %%
datos['Aprobado_final'] = datos['Notas_finales'].apply(lambda x: True if x >= 7.0 else False)

# %% [markdown]
# 4 - Esta selección se puede realizar utilizando el método query:

# %%
datos.query('Aprobado == False & Aprobado_final == True')
# Out:
# Empty DataFrame
# Columns: [Nombre, Edad, Nota, Aprobado, Puntos_extras, Notas_finales, Aprobado_final]
# Index: []

# %% [markdown]
# O también se puede hacer de manera más manual:

# %%
seleccion = (datos['Aprobado'] == False) & (datos['Aprobado_final'] == True)
datos[seleccion]
# Out:
# Empty DataFrame
# Columns: [Nombre, Edad, Nota, Aprobado, Puntos_extras, Notas_finales, Aprobado_final]
# Index: []
